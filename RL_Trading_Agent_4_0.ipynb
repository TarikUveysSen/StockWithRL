# %% [markdown]
# <a href="https://colab.research.google.com/github/eminshall/Reinforcment-Learning-Agent-for-Stock-Trading-AAPL/blob/main/RL_Trading_Agent_4_0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install git+https://github.com/DLR-RM/stable-baselines3@feat/gymnasium-support
# !pip install git+https://github.com/Stable-Baselines-Team/stable-baselines3-contrib@feat/gymnasium-support

# %%
# pip install gym-anytrading

# %%
# pip install shimmy>=0.2.1

# %%
# !pip install finta

# %%
# !pip install quantstats

# %%
import warnings

# Suppress the specific DeprecationWarning
warnings.filterwarnings("ignore", category=DeprecationWarning)

# %%
# Gym stuff
import gym
import gym_anytrading
from gym_anytrading.envs import StocksEnv

# Stable baselines - rl stuff
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3 import A2C

#Quant Finance
from finta import TA
import quantstats as qs

# Processing libraries
import os
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %%
data = pd.read_csv("tickers.csv")

# %%
data = data[data.tic == "^TNX"]

# %%
data.head()
# Out:
#    Unnamed: 0        date   open   high    low  close  volume   tic  day
# 1           2  2000-01-04  6.530  6.548  6.485  6.485       0  ^TNX    1
# 3           4  2000-01-05  6.521  6.599  6.508  6.599       0  ^TNX    2
# 5           6  2000-01-06  6.558  6.585  6.540  6.549       0  ^TNX    3
# 7           8  2000-01-07  6.545  6.595  6.504  6.504       0  ^TNX    4
# 9          11  2000-01-11  6.600  6.664  6.595  6.664       0  ^TNX    6

# %%
data = data.drop(["Unnamed: 0", "tic", "day"], axis=1)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5727 entries, 1 to 11453
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    5727 non-null   object
#  1   open    5727 non-null   float64
#  2   high    5727 non-null   float64
#  3   low     5727 non-null   float64
#  4   close   5727 non-null   float64
#  5   volume  5727 non-null   int64
# dtypes: float64(4), int64(1), object(1)
# memory usage: 313.2+ KB

# %%
data = data.rename(columns = {'open': 'Open', 'high': 'High', 'low': 'Low', 'close': 'Close', 'volume': 'Volume'})

data['date'] = pd.to_datetime(data['date'])
data.set_index('date', inplace=True)
data.sort_values('date', ascending=True, inplace=True)

data.head()
# Out:
#              Open   High    Low  Close  Volume
# date
# 2000-01-04  6.530  6.548  6.485  6.485       0
# 2000-01-05  6.521  6.599  6.508  6.599       0
# 2000-01-06  6.558  6.585  6.540  6.549       0
# 2000-01-07  6.545  6.595  6.504  6.504       0
# 2000-01-11  6.600  6.664  6.595  6.664       0

# %% [markdown]
# ## Add Custom Indicators

# %%
data['return'] = np.log(data['Close'] / data['Close'].shift(1))

# %%
#Create columns for technical indicators & add them to the dataframe
data['RSI'] = TA.RSI(data,16)
data['SMA'] = TA.SMA(data, 20)
data['SMA_L'] = TA.SMA(data, 41)
data['OBV'] = TA.OBV(data)
data['VWAP'] = TA.VWAP(data)
data['EMA'] = TA.EMA(data)
data['ATR'] = TA.ATR(data)
data.fillna(0, inplace=True)

# %%
#Add momentum, volatitlity, & distance to the data_frame
data['momentum'] = data['return'].rolling(5).mean().shift(1)
data['volatility'] = data['return'].rolling(20).std().shift(1)
data['distance'] = (data['Close'] - data['Close'].rolling(50).mean()).shift(1)

# %%
#Perform a simple linear regression direction prediction
lags = 5

cols = []
for lag in range(1, lags + 1):
  col = f'lag_{lag}'
  data[col] = data['Close'].shift(lag)
  cols.append(col)

data.dropna(inplace=True)

reg = np.linalg.lstsq(data[cols], data['Close'], rcond=None)[0]
data['Prediction'] = np.dot(data[cols], reg)

# %%
data.tail()
# Out:
#              Open   High    Low  Close  Volume    return        RSI      SMA  \
# date
# 2023-09-13  4.312  4.344  4.235  4.249       0 -0.003524  56.143707  4.24285
# 2023-09-14  4.229  4.298  4.223  4.288       0  0.009137  58.516780  4.24620
# 2023-09-15  4.320  4.338  4.303  4.322       0  0.007898  60.504121  4.24940
# 2023-09-18  4.337  4.359  4.311  4.319       0 -0.000694  60.232514  4.24995
# 2023-09-19  4.333  4.365  4.325  4.365       0  0.010594  62.952358  4.25565
#
#                SMA_L       OBV  ...       ATR  momentum  volatility  distance  \
# date                            ...
# 2023-09-13  4.106390  631500.0  ...  0.077429 -0.000188    0.013608   0.19996
# 2023-09-14  4.118366  631500.0  ...  0.072929 -0.001921    0.013631   0.17534
# 2023-09-15  4.131366  631500.0  ...  0.073000  0.001310    0.013641   0.20574
# 2023-09-18  4.145439  631500.0  ...  0.070643  0.002984    0.013617   0.23220
# 2023-09-19  4.157902  631500.0  ...  0.070714  0.001441    0.013374   0.22364
#
#             lag_1  lag_2  lag_3  lag_4  lag_5  Prediction
# date
# 2023-09-13  4.264  4.288  4.258  4.260  4.290    4.261579
# 2023-09-14  4.249  4.264  4.288  4.258  4.260    4.248713
# 2023-09-15  4.288  4.249  4.264  4.288  4.258    4.287500
# 2023-09-18  4.322  4.288  4.249  4.264  4.288    4.319068
# 2023-09-19  4.319  4.322  4.288  4.249  4.264    4.316102
#
# [5 rows x 22 columns]

# %%
#Create a function to properly format data frame to be passed through environment
def signals(env):
    start = env.frame_bound[0] - env.window_size
    end = env.frame_bound[1]
    prices = env.df.loc[:,'Close'].to_numpy()[start:end]
    signal_features = env.df.loc[:, ['Open','High','Low','Close','Volume','return','momentum','volatility','distance','RSI','OBV','SMA','SMA_L','VWAP','EMA','ATR', 'Prediction']].to_numpy()[start:end]
    return prices, signal_features

# %%
#Replace default data process with custom function from above
class MyCustomEnv(StocksEnv):
    _process_data = signals

#Initialize an environment setting the window size and train data
window_size = 65
start_index = window_size
end_train_index = round(len(data)*0.70)
end_val_index = len(data)

env2 = MyCustomEnv(df=data, window_size=window_size, frame_bound=(start_index, end_train_index))

# %%
#Create a Dummy Vector of our environment
env_maker = lambda: env2
env = DummyVecEnv([env_maker])

# %% [markdown]
# ## Train Test

# %%
#initialize our model and train
policy_kwargs = dict(optimizer_class='RMSpropTFLike', optimizer_kwargs=dict(eps=1e-5))
actor_critic = A2C('MlpPolicy', env, verbose=1)
actor_critic.learn(total_timesteps=500000)
# Out:
# Görüntülenen çıkış son 5000 satıra kısaltıldı.
# |    value_loss         | 6.44e-12  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 403       |
# |    iterations         | 64400     |
# |    time_elapsed       | 797       |
# |    total_timesteps    | 322000    |
# | train/                |           |
# |    entropy_loss       | -6.78e-05 |
# |    explained_variance | -1.66e+03 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 64399     |
# |    policy_loss        | -1.4e-08  |
# |    value_loss         | 1.45e-05  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 404       |
# |    iterations         | 64500     |
# |    time_elapsed       | 798       |
# |    total_timesteps    | 322500    |
# | train/                |           |
# |    entropy_loss       | -6.69e-05 |
# |    explained_variance | -106      |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 64499     |
# |    policy_loss        | -1.05e-08 |
# |    value_loss         | 5.04e-06  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 404       |
# |    iterations         | 64600     |
# |    time_elapsed       | 799       |
# |    total_timesteps    | 323000    |
# | train/                |           |
# |    entropy_loss       | -6.74e-05 |
# |    explained_variance | -308      |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 64599     |
# |    policy_loss        | 2.69e-09  |
# |    value_loss         | 2.58e-06  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 404       |
# |    iterations         | 64700     |
# |    time_elapsed       | 800       |
# |    total_timesteps    | 323500    |
# | train/                |           |
# |    entropy_loss       | -6.84e-05 |
# |    explained_variance | -405      |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 64699     |
# |    policy_loss        | -3.68e-08 |
# |    value_loss         | 7.36e-05  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 404       |
# |    iterations         | 64800     |
# |    time_elapsed       | 801       |
# |    total_timesteps    | 324000    |
# | train/                |           |
# |    entropy_loss       | -7.17e-05 |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 64799     |
# |    policy_loss        | 8.73e-13  |
# |    value_loss         | 2.9e-14   |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 404       |
# |    iterations         | 64900     |
# |    time_elapsed       | 802       |
# |    total_timesteps    | 324500    |
# | train/                |           |
# |    entropy_loss       | -0.000108 |
# |    explained_variance | -507      |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 64899     |
# |    policy_loss        | 6.29e-13  |
# |    value_loss         | 2.71e-15  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 404       |
# |    iterations         | 65000     |
# |    time_elapsed       | 803       |
# |    total_timesteps    | 325000    |
# | train/                |           |
# |    entropy_loss       | -0.000108 |
# |    explained_variance | -7.7      |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 64999     |
# |    policy_loss        | -1.02e-13 |
# |    value_loss         | 1.19e-15  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 404      |
# |    iterations         | 65100    |
# |    time_elapsed       | 805      |
# |    total_timesteps    | 325500   |
# | train/                |          |
# |    entropy_loss       | -0.00351 |
# |    explained_variance | -566     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 65099    |
# |    policy_loss        | 1.34e-06 |
# |    value_loss         | 0.000338 |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 404       |
# |    iterations         | 65200     |
# |    time_elapsed       | 806       |
# |    total_timesteps    | 326000    |
# | train/                |           |
# |    entropy_loss       | -7.23e-05 |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 65199     |
# |    policy_loss        | 5.59e-11  |
# |    value_loss         | 1.37e-10  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 404       |
# |    iterations         | 65300     |
# |    time_elapsed       | 807       |
# |    total_timesteps    | 326500    |
# | train/                |           |
# |    entropy_loss       | -7.23e-05 |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 65299     |
# |    policy_loss        | -4.91e-09 |
# |    value_loss         | 8.76e-07  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 404       |
# |    iterations         | 65400     |
# |    time_elapsed       | 809       |
# |    total_timesteps    | 327000    |
# | train/                |           |
# |    entropy_loss       | -7.2e-05  |
# |    explained_variance | -104      |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 65399     |
# |    policy_loss        | -1.81e-08 |
# |    value_loss         | 2.1e-05   |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 404       |
# |    iterations         | 65500     |
# |    time_elapsed       | 810       |
# |    total_timesteps    | 327500    |
# | train/                |           |
# |    entropy_loss       | -7.41e-05 |
# |    explained_variance | -85.3     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 65499     |
# |    policy_loss        | -1.88e-08 |
# |    value_loss         | 5.5e-05   |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 404       |
# |    iterations         | 65600     |
# |    time_elapsed       | 811       |
# |    total_timesteps    | 328000    |
# | train/                |           |
# |    entropy_loss       | -6.58e-05 |
# |    explained_variance | -113      |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 65599     |
# |    policy_loss        | -5.09e-09 |
# |    value_loss         | 1.19e-06  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 404       |
# |    iterations         | 65700     |
# |    time_elapsed       | 812       |
# |    total_timesteps    | 328500    |
# | train/                |           |
# |    entropy_loss       | -0.000108 |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 65699     |
# |    policy_loss        | 2.73e-13  |
# |    value_loss         | 9.94e-16  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 404       |
# |    iterations         | 65800     |
# |    time_elapsed       | 813       |
# |    total_timesteps    | 329000    |
# | train/                |           |
# |    entropy_loss       | -0.000108 |
# |    explained_variance | -0.614    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 65799     |
# |    policy_loss        | -5.66e-12 |
# |    value_loss         | 5.19e-13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 404       |
# |    iterations         | 65900     |
# |    time_elapsed       | 814       |
# |    total_timesteps    | 329500    |
# | train/                |           |
# |    entropy_loss       | -6.69e-05 |
# |    explained_variance | -17.9     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 65899     |
# |    policy_loss        | 4.82e-08  |
# |    value_loss         | 0.000115  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 404       |
# |    iterations         | 66000     |
# |    time_elapsed       | 816       |
# |    total_timesteps    | 330000    |
# | train/                |           |
# |    entropy_loss       | -7.34e-05 |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 65999     |
# |    policy_loss        | -2.77e-11 |
# |    value_loss         | 2.92e-11  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 404       |
# |    iterations         | 66100     |
# |    time_elapsed       | 817       |
# |    total_timesteps    | 330500    |
# | train/                |           |
# |    entropy_loss       | -7.34e-05 |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 66099     |
# |    policy_loss        | -1.03e-09 |
# |    value_loss         | 3.91e-08  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 404       |
# |    iterations         | 66200     |
# |    time_elapsed       | 818       |
# |    total_timesteps    | 331000    |
# | train/                |           |
# |    entropy_loss       | -7.34e-05 |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 66199     |
# |    policy_loss        | 7.86e-10  |
# |    value_loss         | 2.29e-08  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 404       |
# |    iterations         | 66300     |
# |    time_elapsed       | 819       |
# |    total_timesteps    | 331500    |
# | train/                |           |
# |    entropy_loss       | -7.34e-05 |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 66299     |
# |    policy_loss        | -7.09e-11 |
# |    value_loss         | 1.89e-10  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 404       |
# |    iterations         | 66400     |
# |    time_elapsed       | 821       |
# |    total_timesteps    | 332000    |
# | train/                |           |
# |    entropy_loss       | -6.87e-05 |
# |    explained_variance | -75.5     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 66399     |
# |    policy_loss        | 2.82e-09  |
# |    value_loss         | 1.42e-06  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 404       |
# |    iterations         | 66500     |
# |    time_elapsed       | 822       |
# |    total_timesteps    | 332500    |
# | train/                |           |
# |    entropy_loss       | -0.000111 |
# |    explained_variance | -3.38     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 66499     |
# |    policy_loss        | -6.19e-12 |
# |    value_loss         | 7.86e-13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 404       |
# |    iterations         | 66600     |
# |    time_elapsed       | 823       |
# |    total_timesteps    | 333000    |
# | train/                |           |
# |    entropy_loss       | -0.000111 |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 66599     |
# |    policy_loss        | 5.42e-13  |
# |    value_loss         | 4.86e-15  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 404      |
# |    iterations         | 66700    |
# |    time_elapsed       | 824      |
# |    total_timesteps    | 333500   |
# | train/                |          |
# |    entropy_loss       | -7.3e-05 |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 66699    |
# |    policy_loss        | 1.07e-09 |
# |    value_loss         | 4.26e-08 |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 404       |
# |    iterations         | 66800     |
# |    time_elapsed       | 825       |
# |    total_timesteps    | 334000    |
# | train/                |           |
# |    entropy_loss       | -6.76e-05 |
# |    explained_variance | -499      |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 66799     |
# |    policy_loss        | -1.6e-08  |
# |    value_loss         | 1.22e-05  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 404       |
# |    iterations         | 66900     |
# |    time_elapsed       | 827       |
# |    total_timesteps    | 334500    |
# | train/                |           |
# |    entropy_loss       | -6.85e-05 |
# |    explained_variance | -70.6     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 66899     |
# |    policy_loss        | 5.07e-09  |
# |    value_loss         | 2.39e-06  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 404       |
# |    iterations         | 67000     |
# |    time_elapsed       | 828       |
# |    total_timesteps    | 335000    |
# | train/                |           |
# |    entropy_loss       | -7.3e-05  |
# |    explained_variance | 5.96e-08  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 66999     |
# |    policy_loss        | -1.82e-09 |
# |    value_loss         | 1.23e-07  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 404      |
# |    iterations         | 67100    |
# |    time_elapsed       | 829      |
# |    total_timesteps    | 335500   |
# | train/                |          |
# |    entropy_loss       | -7.3e-05 |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 67099    |
# |    policy_loss        | 2.52e-14 |
# |    value_loss         | 1.45e-16 |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 404       |
# |    iterations         | 67200     |
# |    time_elapsed       | 830       |
# |    total_timesteps    | 336000    |
# | train/                |           |
# |    entropy_loss       | -7.3e-05  |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 67199     |
# |    policy_loss        | -4.22e-13 |
# |    value_loss         | 1.04e-14  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 404      |
# |    iterations         | 67300    |
# |    time_elapsed       | 831      |
# |    total_timesteps    | 336500   |
# | train/                |          |
# |    entropy_loss       | -0.00011 |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 67299    |
# |    policy_loss        | 1.67e-10 |
# |    value_loss         | 4.61e-10 |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 404       |
# |    iterations         | 67400     |
# |    time_elapsed       | 833       |
# |    total_timesteps    | 337000    |
# | train/                |           |
# |    entropy_loss       | -0.00011  |
# |    explained_variance | -0.000391 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 67399     |
# |    policy_loss        | 1.37e-09  |
# |    value_loss         | 3.12e-08  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 404       |
# |    iterations         | 67500     |
# |    time_elapsed       | 834       |
# |    total_timesteps    | 337500    |
# | train/                |           |
# |    entropy_loss       | -7.18e-05 |
# |    explained_variance | -49.1     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 67499     |
# |    policy_loss        | -3.25e-09 |
# |    value_loss         | 8.18e-06  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 404       |
# |    iterations         | 67600     |
# |    time_elapsed       | 835       |
# |    total_timesteps    | 338000    |
# | train/                |           |
# |    entropy_loss       | -6.28e-05 |
# |    explained_variance | -750      |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 67599     |
# |    policy_loss        | 1.91e-09  |
# |    value_loss         | 2.61e-06  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 404       |
# |    iterations         | 67700     |
# |    time_elapsed       | 836       |
# |    total_timesteps    | 338500    |
# | train/                |           |
# |    entropy_loss       | -7.13e-05 |
# |    explained_variance | 0.00604   |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 67699     |
# |    policy_loss        | -7.97e-10 |
# |    value_loss         | 2.84e-08  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 404       |
# |    iterations         | 67800     |
# |    time_elapsed       | 838       |
# |    total_timesteps    | 339000    |
# | train/                |           |
# |    entropy_loss       | -6.74e-05 |
# |    explained_variance | -78.6     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 67799     |
# |    policy_loss        | -8.34e-10 |
# |    value_loss         | 6.25e-07  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 404       |
# |    iterations         | 67900     |
# |    time_elapsed       | 839       |
# |    total_timesteps    | 339500    |
# | train/                |           |
# |    entropy_loss       | -6.75e-05 |
# |    explained_variance | -44.4     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 67899     |
# |    policy_loss        | 5.07e-08  |
# |    value_loss         | 9.69e-05  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 404       |
# |    iterations         | 68000     |
# |    time_elapsed       | 840       |
# |    total_timesteps    | 340000    |
# | train/                |           |
# |    entropy_loss       | -7.08e-05 |
# |    explained_variance | -22.5     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 67999     |
# |    policy_loss        | -3.31e-10 |
# |    value_loss         | 1.18e-07  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 404       |
# |    iterations         | 68100     |
# |    time_elapsed       | 841       |
# |    total_timesteps    | 340500    |
# | train/                |           |
# |    entropy_loss       | -0.000108 |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 68099     |
# |    policy_loss        | 2.68e-12  |
# |    value_loss         | 1.01e-13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 404       |
# |    iterations         | 68200     |
# |    time_elapsed       | 842       |
# |    total_timesteps    | 341000    |
# | train/                |           |
# |    entropy_loss       | -0.000108 |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 68199     |
# |    policy_loss        | 1.05e-10  |
# |    value_loss         | 1.83e-10  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 404       |
# |    iterations         | 68300     |
# |    time_elapsed       | 843       |
# |    total_timesteps    | 341500    |
# | train/                |           |
# |    entropy_loss       | -6.63e-05 |
# |    explained_variance | -240      |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 68299     |
# |    policy_loss        | -4.6e-09  |
# |    value_loss         | 5.03e-06  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 404       |
# |    iterations         | 68400     |
# |    time_elapsed       | 845       |
# |    total_timesteps    | 342000    |
# | train/                |           |
# |    entropy_loss       | -7.04e-05 |
# |    explained_variance | -5.68e+03 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 68399     |
# |    policy_loss        | -1.78e-10 |
# |    value_loss         | 7.69e-07  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 404       |
# |    iterations         | 68500     |
# |    time_elapsed       | 846       |
# |    total_timesteps    | 342500    |
# | train/                |           |
# |    entropy_loss       | -7.16e-05 |
# |    explained_variance | -14.1     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 68499     |
# |    policy_loss        | -4.29e-09 |
# |    value_loss         | 1.26e-06  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 404       |
# |    iterations         | 68600     |
# |    time_elapsed       | 847       |
# |    total_timesteps    | 343000    |
# | train/                |           |
# |    entropy_loss       | -6.98e-05 |
# |    explained_variance | -28.5     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 68599     |
# |    policy_loss        | -1.59e-08 |
# |    value_loss         | 1.66e-05  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 404       |
# |    iterations         | 68700     |
# |    time_elapsed       | 849       |
# |    total_timesteps    | 343500    |
# | train/                |           |
# |    entropy_loss       | -7.17e-05 |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 68699     |
# |    policy_loss        | 9.91e-12  |
# |    value_loss         | 4.43e-12  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 404       |
# |    iterations         | 68800     |
# |    time_elapsed       | 850       |
# |    total_timesteps    | 344000    |
# | train/                |           |
# |    entropy_loss       | -0.000108 |
# |    explained_variance | 0.401     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 68799     |
# |    policy_loss        | 1.25e-12  |
# |    value_loss         | 2.47e-14  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 404       |
# |    iterations         | 68900     |
# |    time_elapsed       | 851       |
# |    total_timesteps    | 344500    |
# | train/                |           |
# |    entropy_loss       | -0.000108 |
# |    explained_variance | -8.54e-05 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 68899     |
# |    policy_loss        | -1.65e-11 |
# |    value_loss         | 4.24e-12  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 404       |
# |    iterations         | 69000     |
# |    time_elapsed       | 852       |
# |    total_timesteps    | 345000    |
# | train/                |           |
# |    entropy_loss       | -0.000108 |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 68999     |
# |    policy_loss        | -2.08e-09 |
# |    value_loss         | 7.18e-08  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 404       |
# |    iterations         | 69100     |
# |    time_elapsed       | 853       |
# |    total_timesteps    | 345500    |
# | train/                |           |
# |    entropy_loss       | -6.58e-05 |
# |    explained_variance | -120      |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 69099     |
# |    policy_loss        | -6.24e-09 |
# |    value_loss         | 4.86e-06  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 404       |
# |    iterations         | 69200     |
# |    time_elapsed       | 854       |
# |    total_timesteps    | 346000    |
# | train/                |           |
# |    entropy_loss       | -7.15e-05 |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 69199     |
# |    policy_loss        | -8.79e-10 |
# |    value_loss         | 3.41e-08  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 404       |
# |    iterations         | 69300     |
# |    time_elapsed       | 856       |
# |    total_timesteps    | 346500    |
# | train/                |           |
# |    entropy_loss       | -6.44e-05 |
# |    explained_variance | -1.14e+03 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 69299     |
# |    policy_loss        | 3.21e-10  |
# |    value_loss         | 1.89e-06  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 404       |
# |    iterations         | 69400     |
# |    time_elapsed       | 857       |
# |    total_timesteps    | 347000    |
# | train/                |           |
# |    entropy_loss       | -6.51e-05 |
# |    explained_variance | -30.2     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 69399     |
# |    policy_loss        | -5.68e-09 |
# |    value_loss         | 4.32e-06  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 404       |
# |    iterations         | 69500     |
# |    time_elapsed       | 858       |
# |    total_timesteps    | 347500    |
# | train/                |           |
# |    entropy_loss       | -6.67e-05 |
# |    explained_variance | -2.52     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 69499     |
# |    policy_loss        | 3.43e-09  |
# |    value_loss         | 6.1e-07   |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 404       |
# |    iterations         | 69600     |
# |    time_elapsed       | 860       |
# |    total_timesteps    | 348000    |
# | train/                |           |
# |    entropy_loss       | -0.000108 |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 69599     |
# |    policy_loss        | 3.5e-14   |
# |    value_loss         | 1.21e-16  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 404       |
# |    iterations         | 69700     |
# |    time_elapsed       | 861       |
# |    total_timesteps    | 348500    |
# | train/                |           |
# |    entropy_loss       | -0.000108 |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 69699     |
# |    policy_loss        | 7.29e-14  |
# |    value_loss         | 8.78e-17  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 404       |
# |    iterations         | 69800     |
# |    time_elapsed       | 862       |
# |    total_timesteps    | 349000    |
# | train/                |           |
# |    entropy_loss       | -8.41e-05 |
# |    explained_variance | -18.6     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 69799     |
# |    policy_loss        | 5.31e-08  |
# |    value_loss         | 0.000182  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 404       |
# |    iterations         | 69900     |
# |    time_elapsed       | 863       |
# |    total_timesteps    | 349500    |
# | train/                |           |
# |    entropy_loss       | -7.18e-05 |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 69899     |
# |    policy_loss        | -4.66e-11 |
# |    value_loss         | 9.45e-11  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 404       |
# |    iterations         | 70000     |
# |    time_elapsed       | 864       |
# |    total_timesteps    | 350000    |
# | train/                |           |
# |    entropy_loss       | -6.88e-05 |
# |    explained_variance | -8.77     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 69999     |
# |    policy_loss        | 4.91e-09  |
# |    value_loss         | 1.37e-06  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 404       |
# |    iterations         | 70100     |
# |    time_elapsed       | 865       |
# |    total_timesteps    | 350500    |
# | train/                |           |
# |    entropy_loss       | -7.18e-05 |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 70099     |
# |    policy_loss        | -2.37e-09 |
# |    value_loss         | 2.49e-07  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 404       |
# |    iterations         | 70200     |
# |    time_elapsed       | 867       |
# |    total_timesteps    | 351000    |
# | train/                |           |
# |    entropy_loss       | -6.52e-05 |
# |    explained_variance | -1.85     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 70199     |
# |    policy_loss        | -6.61e-09 |
# |    value_loss         | 2.25e-06  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 404       |
# |    iterations         | 70300     |
# |    time_elapsed       | 868       |
# |    total_timesteps    | 351500    |
# | train/                |           |
# |    entropy_loss       | -7.18e-05 |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 70299     |
# |    policy_loss        | -1.67e-12 |
# |    value_loss         | 1.76e-13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 404       |
# |    iterations         | 70400     |
# |    time_elapsed       | 869       |
# |    total_timesteps    | 352000    |
# | train/                |           |
# |    entropy_loss       | -0.000108 |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 70399     |
# |    policy_loss        | 6.65e-13  |
# |    value_loss         | 1.32e-14  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 404       |
# |    iterations         | 70500     |
# |    time_elapsed       | 870       |
# |    total_timesteps    | 352500    |
# | train/                |           |
# |    entropy_loss       | -0.000108 |
# |    explained_variance | 0.000363  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 70499     |
# |    policy_loss        | 1.49e-09  |
# |    value_loss         | 3.66e-08  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 404       |
# |    iterations         | 70600     |
# |    time_elapsed       | 872       |
# |    total_timesteps    | 353000    |
# | train/                |           |
# |    entropy_loss       | -6.66e-05 |
# |    explained_variance | -73.9     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 70599     |
# |    policy_loss        | 3.72e-08  |
# |    value_loss         | 6.37e-05  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 404      |
# |    iterations         | 70700    |
# |    time_elapsed       | 873      |
# |    total_timesteps    | 353500   |
# | train/                |          |
# |    entropy_loss       | -7.2e-05 |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 70699    |
# |    policy_loss        | 4.31e-12 |
# |    value_loss         | 9.1e-13  |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 404      |
# |    iterations         | 70800    |
# |    time_elapsed       | 874      |
# |    total_timesteps    | 354000   |
# | train/                |          |
# |    entropy_loss       | -7.2e-05 |
# |    explained_variance | 1.19e-07 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 70799    |
# |    policy_loss        | 3.3e-11  |
# |    value_loss         | 4.87e-11 |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 404       |
# |    iterations         | 70900     |
# |    time_elapsed       | 875       |
# |    total_timesteps    | 354500    |
# | train/                |           |
# |    entropy_loss       | -6.74e-05 |
# |    explained_variance | -10.1     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 70899     |
# |    policy_loss        | 4.21e-09  |
# |    value_loss         | 2.69e-06  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 404      |
# |    iterations         | 71000    |
# |    time_elapsed       | 876      |
# |    total_timesteps    | 355000   |
# | train/                |          |
# |    entropy_loss       | -7.2e-05 |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 70999    |
# |    policy_loss        | 3.42e-13 |
# |    value_loss         | 2.18e-15 |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 404       |
# |    iterations         | 71100     |
# |    time_elapsed       | 877       |
# |    total_timesteps    | 355500    |
# | train/                |           |
# |    entropy_loss       | -7.2e-05  |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 71099     |
# |    policy_loss        | -4.19e-10 |
# |    value_loss         | 7.77e-09  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 404       |
# |    iterations         | 71200     |
# |    time_elapsed       | 879       |
# |    total_timesteps    | 356000    |
# | train/                |           |
# |    entropy_loss       | -0.000107 |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 71199     |
# |    policy_loss        | 3.68e-11  |
# |    value_loss         | 2.26e-11  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 405       |
# |    iterations         | 71300     |
# |    time_elapsed       | 880       |
# |    total_timesteps    | 356500    |
# | train/                |           |
# |    entropy_loss       | -0.000107 |
# |    explained_variance | 5.96e-08  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 71299     |
# |    policy_loss        | 2.74e-09  |
# |    value_loss         | 1.24e-07  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 405       |
# |    iterations         | 71400     |
# |    time_elapsed       | 881       |
# |    total_timesteps    | 357000    |
# | train/                |           |
# |    entropy_loss       | -6.98e-05 |
# |    explained_variance | -333      |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 71399     |
# |    policy_loss        | 2.15e-08  |
# |    value_loss         | 3.67e-05  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 405       |
# |    iterations         | 71500     |
# |    time_elapsed       | 882       |
# |    total_timesteps    | 357500    |
# | train/                |           |
# |    entropy_loss       | -7.09e-05 |
# |    explained_variance | -5.1      |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 71499     |
# |    policy_loss        | 7.6e-10   |
# |    value_loss         | 1.87e-06  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 404       |
# |    iterations         | 71600     |
# |    time_elapsed       | 884       |
# |    total_timesteps    | 358000    |
# | train/                |           |
# |    entropy_loss       | -6.84e-05 |
# |    explained_variance | -9.03     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 71599     |
# |    policy_loss        | 3.5e-08   |
# |    value_loss         | 4.87e-05  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 404       |
# |    iterations         | 71700     |
# |    time_elapsed       | 885       |
# |    total_timesteps    | 358500    |
# | train/                |           |
# |    entropy_loss       | -7.29e-05 |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 71699     |
# |    policy_loss        | 5.3e-11   |
# |    value_loss         | 1.06e-10  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 404       |
# |    iterations         | 71800     |
# |    time_elapsed       | 886       |
# |    total_timesteps    | 359000    |
# | train/                |           |
# |    entropy_loss       | -6.61e-05 |
# |    explained_variance | -8.38     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 71799     |
# |    policy_loss        | -1.64e-08 |
# |    value_loss         | 1.24e-05  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 404       |
# |    iterations         | 71900     |
# |    time_elapsed       | 887       |
# |    total_timesteps    | 359500    |
# | train/                |           |
# |    entropy_loss       | -6.53e-05 |
# |    explained_variance | -24.3     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 71899     |
# |    policy_loss        | -2.85e-09 |
# |    value_loss         | 1.23e-06  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 404       |
# |    iterations         | 72000     |
# |    time_elapsed       | 888       |
# |    total_timesteps    | 360000    |
# | train/                |           |
# |    entropy_loss       | -0.000107 |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 71999     |
# |    policy_loss        | 8.67e-13  |
# |    value_loss         | 9.63e-15  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 405       |
# |    iterations         | 72100     |
# |    time_elapsed       | 890       |
# |    total_timesteps    | 360500    |
# | train/                |           |
# |    entropy_loss       | -0.000107 |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 72099     |
# |    policy_loss        | 4.33e-10  |
# |    value_loss         | 3.09e-09  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 405       |
# |    iterations         | 72200     |
# |    time_elapsed       | 891       |
# |    total_timesteps    | 361000    |
# | train/                |           |
# |    entropy_loss       | -6.62e-05 |
# |    explained_variance | -24.8     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 72199     |
# |    policy_loss        | -7.93e-09 |
# |    value_loss         | 6.37e-06  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 405       |
# |    iterations         | 72300     |
# |    time_elapsed       | 892       |
# |    total_timesteps    | 361500    |
# | train/                |           |
# |    entropy_loss       | -7.28e-05 |
# |    explained_variance | -43       |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 72299     |
# |    policy_loss        | 7.07e-10  |
# |    value_loss         | 2.68e-07  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 405       |
# |    iterations         | 72400     |
# |    time_elapsed       | 893       |
# |    total_timesteps    | 362000    |
# | train/                |           |
# |    entropy_loss       | -6.44e-05 |
# |    explained_variance | -28.4     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 72399     |
# |    policy_loss        | -9.2e-10  |
# |    value_loss         | 2.51e-06  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 405       |
# |    iterations         | 72500     |
# |    time_elapsed       | 894       |
# |    total_timesteps    | 362500    |
# | train/                |           |
# |    entropy_loss       | -6.91e-05 |
# |    explained_variance | -145      |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 72499     |
# |    policy_loss        | 3.42e-09  |
# |    value_loss         | 1.27e-06  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 404       |
# |    iterations         | 72600     |
# |    time_elapsed       | 896       |
# |    total_timesteps    | 363000    |
# | train/                |           |
# |    entropy_loss       | -6.87e-05 |
# |    explained_variance | -16.8     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 72599     |
# |    policy_loss        | 9.46e-10  |
# |    value_loss         | 1.47e-07  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 404       |
# |    iterations         | 72700     |
# |    time_elapsed       | 897       |
# |    total_timesteps    | 363500    |
# | train/                |           |
# |    entropy_loss       | -0.000107 |
# |    explained_variance | -84.8     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 72699     |
# |    policy_loss        | 5e-13     |
# |    value_loss         | 2.31e-15  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 404       |
# |    iterations         | 72800     |
# |    time_elapsed       | 898       |
# |    total_timesteps    | 364000    |
# | train/                |           |
# |    entropy_loss       | -0.000107 |
# |    explained_variance | -0.144    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 72799     |
# |    policy_loss        | -1.48e-12 |
# |    value_loss         | 3.98e-14  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 404       |
# |    iterations         | 72900     |
# |    time_elapsed       | 900       |
# |    total_timesteps    | 364500    |
# | train/                |           |
# |    entropy_loss       | -0.000107 |
# |    explained_variance | -0.000155 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 72899     |
# |    policy_loss        | 9.94e-10  |
# |    value_loss         | 1.63e-08  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 405       |
# |    iterations         | 73000     |
# |    time_elapsed       | 901       |
# |    total_timesteps    | 365000    |
# | train/                |           |
# |    entropy_loss       | -6.52e-05 |
# |    explained_variance | -27.9     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 72999     |
# |    policy_loss        | -3.3e-09  |
# |    value_loss         | 7.28e-07  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 405      |
# |    iterations         | 73100    |
# |    time_elapsed       | 902      |
# |    total_timesteps    | 365500   |
# | train/                |          |
# |    entropy_loss       | -6.8e-05 |
# |    explained_variance | -17.6    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 73099    |
# |    policy_loss        | 6.48e-09 |
# |    value_loss         | 1.79e-06 |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 405       |
# |    iterations         | 73200     |
# |    time_elapsed       | 903       |
# |    total_timesteps    | 366000    |
# | train/                |           |
# |    entropy_loss       | -6.56e-05 |
# |    explained_variance | -444      |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 73199     |
# |    policy_loss        | -4.71e-09 |
# |    value_loss         | 9.79e-07  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 405       |
# |    iterations         | 73300     |
# |    time_elapsed       | 904       |
# |    total_timesteps    | 366500    |
# | train/                |           |
# |    entropy_loss       | -7.45e-05 |
# |    explained_variance | -247      |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 73299     |
# |    policy_loss        | -2.26e-08 |
# |    value_loss         | 2.1e-05   |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# ...
# |    value_loss         | 5.57e-17 |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 406       |
# |    iterations         | 97100     |
# |    time_elapsed       | 1195      |
# |    total_timesteps    | 485500    |
# | train/                |           |
# |    entropy_loss       | -0.00013  |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 97099     |
# |    policy_loss        | -3.83e-13 |
# |    value_loss         | 1.62e-15  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 406       |
# |    iterations         | 97200     |
# |    time_elapsed       | 1196      |
# |    total_timesteps    | 486000    |
# | train/                |           |
# |    entropy_loss       | -8.69e-05 |
# |    explained_variance | -127      |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 97199     |
# |    policy_loss        | -4.9e-08  |
# |    value_loss         | 0.000159  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 406       |
# |    iterations         | 97300     |
# |    time_elapsed       | 1198      |
# |    total_timesteps    | 486500    |
# | train/                |           |
# |    entropy_loss       | -9.01e-05 |
# |    explained_variance | -304      |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 97299     |
# |    policy_loss        | -3.85e-08 |
# |    value_loss         | 4.13e-05  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 406       |
# |    iterations         | 97400     |
# |    time_elapsed       | 1199      |
# |    total_timesteps    | 487000    |
# | train/                |           |
# |    entropy_loss       | -8.15e-05 |
# |    explained_variance | -10.6     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 97399     |
# |    policy_loss        | 4.08e-08  |
# |    value_loss         | 4.38e-05  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 406       |
# |    iterations         | 97500     |
# |    time_elapsed       | 1200      |
# |    total_timesteps    | 487500    |
# | train/                |           |
# |    entropy_loss       | -8.08e-05 |
# |    explained_variance | -264      |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 97499     |
# |    policy_loss        | -6.27e-09 |
# |    value_loss         | 3.4e-06   |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 406       |
# |    iterations         | 97600     |
# |    time_elapsed       | 1201      |
# |    total_timesteps    | 488000    |
# | train/                |           |
# |    entropy_loss       | -8.61e-05 |
# |    explained_variance | -25       |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 97599     |
# |    policy_loss        | 1.58e-09  |
# |    value_loss         | 3.69e-07  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 406       |
# |    iterations         | 97700     |
# |    time_elapsed       | 1202      |
# |    total_timesteps    | 488500    |
# | train/                |           |
# |    entropy_loss       | -8.14e-05 |
# |    explained_variance | -7.11     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 97699     |
# |    policy_loss        | -4.46e-09 |
# |    value_loss         | 1.72e-06  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 406       |
# |    iterations         | 97800     |
# |    time_elapsed       | 1204      |
# |    total_timesteps    | 489000    |
# | train/                |           |
# |    entropy_loss       | -0.000118 |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 97799     |
# |    policy_loss        | -3.33e-13 |
# |    value_loss         | 9.21e-15  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 406       |
# |    iterations         | 97900     |
# |    time_elapsed       | 1205      |
# |    total_timesteps    | 489500    |
# | train/                |           |
# |    entropy_loss       | -0.000118 |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 97899     |
# |    policy_loss        | -3.17e-13 |
# |    value_loss         | 4.21e-15  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 406       |
# |    iterations         | 98000     |
# |    time_elapsed       | 1206      |
# |    total_timesteps    | 490000    |
# | train/                |           |
# |    entropy_loss       | -7.77e-05 |
# |    explained_variance | -355      |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 97999     |
# |    policy_loss        | -6.83e-09 |
# |    value_loss         | 9.63e-06  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 406       |
# |    iterations         | 98100     |
# |    time_elapsed       | 1207      |
# |    total_timesteps    | 490500    |
# | train/                |           |
# |    entropy_loss       | -8.23e-05 |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 98099     |
# |    policy_loss        | 2.03e-10  |
# |    value_loss         | 1.31e-09  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 406      |
# |    iterations         | 98200    |
# |    time_elapsed       | 1208     |
# |    total_timesteps    | 491000   |
# | train/                |          |
# |    entropy_loss       | -7.8e-05 |
# |    explained_variance | -0.103   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 98199    |
# |    policy_loss        | 1.31e-08 |
# |    value_loss         | 4.98e-06 |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 406       |
# |    iterations         | 98300     |
# |    time_elapsed       | 1210      |
# |    total_timesteps    | 491500    |
# | train/                |           |
# |    entropy_loss       | -8.23e-05 |
# |    explained_variance | -1.62e+03 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 98299     |
# |    policy_loss        | 5.6e-08   |
# |    value_loss         | 9.49e-05  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 406       |
# |    iterations         | 98400     |
# |    time_elapsed       | 1211      |
# |    total_timesteps    | 492000    |
# | train/                |           |
# |    entropy_loss       | -8.23e-05 |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 98399     |
# |    policy_loss        | 2.54e-10  |
# |    value_loss         | 2.05e-09  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 406      |
# |    iterations         | 98500    |
# |    time_elapsed       | 1212     |
# |    total_timesteps    | 492500   |
# | train/                |          |
# |    entropy_loss       | -0.00011 |
# |    explained_variance | -6.79    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 98499    |
# |    policy_loss        | 6.74e-15 |
# |    value_loss         | 3.26e-16 |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 406       |
# |    iterations         | 98600     |
# |    time_elapsed       | 1213      |
# |    total_timesteps    | 493000    |
# | train/                |           |
# |    entropy_loss       | -0.00011  |
# |    explained_variance | -1.59     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 98599     |
# |    policy_loss        | -1.65e-13 |
# |    value_loss         | 1.02e-15  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 406       |
# |    iterations         | 98700     |
# |    time_elapsed       | 1215      |
# |    total_timesteps    | 493500    |
# | train/                |           |
# |    entropy_loss       | -0.00011  |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 98699     |
# |    policy_loss        | -2.8e-13  |
# |    value_loss         | 1.3e-15   |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 406       |
# |    iterations         | 98800     |
# |    time_elapsed       | 1216      |
# |    total_timesteps    | 494000    |
# | train/                |           |
# |    entropy_loss       | -6.81e-05 |
# |    explained_variance | -3.52     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 98799     |
# |    policy_loss        | -7.16e-09 |
# |    value_loss         | 2.07e-06  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 406       |
# |    iterations         | 98900     |
# |    time_elapsed       | 1217      |
# |    total_timesteps    | 494500    |
# | train/                |           |
# |    entropy_loss       | -7.1e-05  |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 98899     |
# |    policy_loss        | -1.76e-09 |
# |    value_loss         | 1.37e-07  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 406       |
# |    iterations         | 99000     |
# |    time_elapsed       | 1218      |
# |    total_timesteps    | 495000    |
# | train/                |           |
# |    entropy_loss       | -6.82e-05 |
# |    explained_variance | -117      |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 98999     |
# |    policy_loss        | 4.25e-09  |
# |    value_loss         | 1.55e-06  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 406       |
# |    iterations         | 99100     |
# |    time_elapsed       | 1219      |
# |    total_timesteps    | 495500    |
# | train/                |           |
# |    entropy_loss       | -6.51e-05 |
# |    explained_variance | -5.24     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 99099     |
# |    policy_loss        | 7.15e-09  |
# |    value_loss         | 5.27e-06  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 406       |
# |    iterations         | 99200     |
# |    time_elapsed       | 1220      |
# |    total_timesteps    | 496000    |
# | train/                |           |
# |    entropy_loss       | -6.41e-05 |
# |    explained_variance | -124      |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 99199     |
# |    policy_loss        | -4.02e-10 |
# |    value_loss         | 1.51e-06  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 406       |
# |    iterations         | 99300     |
# |    time_elapsed       | 1222      |
# |    total_timesteps    | 496500    |
# | train/                |           |
# |    entropy_loss       | -9.16e-05 |
# |    explained_variance | 0.00896   |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 99299     |
# |    policy_loss        | 5.21e-13  |
# |    value_loss         | 1.17e-15  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 406       |
# |    iterations         | 99400     |
# |    time_elapsed       | 1223      |
# |    total_timesteps    | 497000    |
# | train/                |           |
# |    entropy_loss       | -9.16e-05 |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 99399     |
# |    policy_loss        | -2.86e-13 |
# |    value_loss         | 7.53e-15  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 406       |
# |    iterations         | 99500     |
# |    time_elapsed       | 1224      |
# |    total_timesteps    | 497500    |
# | train/                |           |
# |    entropy_loss       | -9.61e-05 |
# |    explained_variance | -208      |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 99499     |
# |    policy_loss        | -1.23e-07 |
# |    value_loss         | 0.000463  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 406      |
# |    iterations         | 99600    |
# |    time_elapsed       | 1226     |
# |    total_timesteps    | 498000   |
# | train/                |          |
# |    entropy_loss       | -8.8e-05 |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 99599    |
# |    policy_loss        | 7.61e-10 |
# |    value_loss         | 1.58e-08 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 406      |
# |    iterations         | 99700    |
# |    time_elapsed       | 1227     |
# |    total_timesteps    | 498500   |
# | train/                |          |
# |    entropy_loss       | -8.3e-05 |
# |    explained_variance | -21.4    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 99699    |
# |    policy_loss        | 1.21e-08 |
# |    value_loss         | 4.2e-06  |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 406       |
# |    iterations         | 99800     |
# |    time_elapsed       | 1228      |
# |    total_timesteps    | 499000    |
# | train/                |           |
# |    entropy_loss       | -8.82e-05 |
# |    explained_variance | -48.8     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 99799     |
# |    policy_loss        | -1.07e-08 |
# |    value_loss         | 7.06e-06  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 406       |
# |    iterations         | 99900     |
# |    time_elapsed       | 1229      |
# |    total_timesteps    | 499500    |
# | train/                |           |
# |    entropy_loss       | -8.21e-05 |
# |    explained_variance | -53.5     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 99899     |
# |    policy_loss        | -1.86e-08 |
# |    value_loss         | 9.82e-06  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 406      |
# |    iterations         | 100000   |
# |    time_elapsed       | 1230     |
# |    total_timesteps    | 500000   |
# | train/                |          |
# |    entropy_loss       | -8.8e-05 |
# |    explained_variance | 5.96e-08 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 99999    |
# |    policy_loss        | -1.3e-10 |
# |    value_loss         | 4.59e-10 |
# ------------------------------------

# %%
#Create a new environment with validation data
env = MyCustomEnv(df=data, window_size=window_size, frame_bound=(end_train_index, end_val_index))
obs = env.reset()

# %%
# type(obs)

# %%
# obs = np.array(obs)
# obs = obs[np.newaxis, ...]

# %%
# type(obs)

# %%
# #Create a new environment with validation data
# env = MyCustomEnv(df=data, window_size=window_size, frame_bound=(end_train_index, end_val_index))
# obs = env.reset()

# %%
while True:
    obs = obs[np.newaxis, ...]
    action, _states = actor_critic.predict(obs)
    obs, rewards, done, info = env.step(action)
    if done:
        print("info", info)
        break
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-94-1ec92ee2bb9a> in <cell line: 1>()
#       1 while True:
# ----> 2     obs = obs[np.newaxis, ...]
#       3     action, _states = actor_critic.predict(obs)
#       4     obs, rewards, done, info = env.step(action)
#       5     if done:
#
# TypeError: tuple indices must be integers or slices, not tuple

# %%
#Plot the results
plt.figure(figsize=(16,9))
env.render_all()
plt.show()

# %%
qs.extend_pandas()

net_worth = pd.Series(env.history['total_profit'], index=data.index[end_train_index+1:end_val_index])
returns = net_worth.pct_change().iloc[1:]

qs.reports.full(returns)
